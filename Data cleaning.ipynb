# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as snsd

# %%
df = pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/Salaries.csv")

# %%
df.head(12)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778

# %%
df.tail(12)
# Out:
#          rank discipline  phd  service     sex  salary
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max
# Out:
# <bound method DataFrame.max of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.mean('salary')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-cd3b891378d9> in <module>
# ----> 1 df.mean('salary')
#       2
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7389         else:
#    7390             # TODO: Make other agg func handle axis=None properly
# -> 7391             axis = self._get_axis_number(axis)
#    7392             labels = self._get_agg_axis(axis)
# ...

# %%
df.groupby(["salary"]).mean()
# Out:
#               phd    service
# salary
# 57800   51.000000  51.000000
# 62884   25.000000  22.000000
# 63100    7.000000   6.000000
# 71065   12.000000   9.000000
# 72500    2.500000   0.500000
# 73000    4.000000   2.000000
# 73300   26.000000  24.000000
# 73500    5.000000   3.000000
# 74692   11.000000   3.000000
# 74830   13.000000   8.000000
# 75044    8.000000   3.000000
# 77000    5.000000   0.000000
# 77500    7.000000   5.000000
# 78500    8.000000   3.000000
# 80225    4.000000   2.000000
# 81285   20.000000  17.000000
# 85000    2.000000   0.000000
# 88000    1.000000   0.000000
# 90450   17.000000  11.000000
# 91000   16.500000  15.000000
# 91100   30.000000  23.000000
# 91300    7.000000   2.000000
# 92000    3.666667   2.333333
# 93000   12.000000   6.000000
# 94350   29.000000  19.000000
# 97032   10.000000   5.000000
# 99418   35.000000  31.000000
# 102000  20.000000   8.000000
# 103106  33.000000  30.000000
# 103275  27.000000  19.000000
# ...

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df_sub=df[df['salary']>12000]

# %%
df_sub.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df_f=df[df['sex']=='female']

# %%
df_f.describe()
# Out:
#        phd  service  salary
# count  0.0      0.0     0.0
# mean   NaN      NaN     NaN
# std    NaN      NaN     NaN
# min    NaN      NaN     NaN
# 25%    NaN      NaN     NaN
# 50%    NaN      NaN     NaN
# 75%    NaN      NaN     NaN
# max    NaN      NaN     NaN

# %%
df[df['salary']>12000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df_sub.loc[10:20,['rank','sex','salary']]
# Out:
#         rank   sex  salary
# 10      Prof  Male  128250
# 11      Prof  Male  134778
# 12  AsstProf  Male   88000
# 13      Prof  Male  162200
# 14      Prof  Male  153750
# 15      Prof  Male  150480
# 16  AsstProf  Male   75044
# 17  AsstProf  Male   92000
# 18      Prof  Male  107300
# 19      Prof  Male  150500
# 20  AsstProf  Male   92000

# %%
df.loc[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500
# 20  AsstProf          B    4        4  Male   92000

# %%
df.iloc[10:20,['2','3','4']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-7fe60b5b987a> in <module>
# ----> 1 df.iloc[10:20,['2','3','4']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2141     def _getitem_tuple(self, tup):
#    2142
# -> 2143         self._has_valid_tuple(tup)
#    2144         try:
#    2145             return self._getitem_lowerdim(tup)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     221                 raise IndexingError('Too many indexers')
# ...

# %%
#first row of a data frame
df.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
#(i)th row
df.iloc[1]
# Out:
# rank           Prof
# discipline        A
# phd              12
# service           6
# sex            Male
# salary        93000
# Name: 1, dtype: object

# %%
#last row
df.iloc[-2]
# Out:
# rank            Prof
# discipline         A
# phd               28
# service           14
# sex           Female
# salary        109954
# Name: 76, dtype: object

# %%
#first column
df.iloc[:,0]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
# 5          Prof
# 6     AssocProf
# 7          Prof
# 8          Prof
# 9          Prof
# 10         Prof
# 11         Prof
# 12     AsstProf
# 13         Prof
# 14         Prof
# 15         Prof
# 16     AsstProf
# 17     AsstProf
# 18         Prof
# 19         Prof
# 20     AsstProf
# 21         Prof
# 22     AsstProf
# 23     AsstProf
# 24         Prof
# 25         Prof
# 26         Prof
# 27         Prof
# 28     AsstProf
# 29         Prof
#         ...
# 48         Prof
# 49         Prof
# 50     AsstProf
# 51         Prof
# 52         Prof
# 53     AsstProf
# 54    AssocProf
# 55     AsstProf
# 56    AssocProf
# 57     AsstProf
# 58         Prof
# 59    AssocProf
# 60     AsstProf
# 61    AssocProf
# 62    AssocProf
# 63         Prof
# 64    AssocProf
# 65         Prof
# 66     AsstProf
# 67         Prof
# 68     AsstProf
# 69         Prof
# 70     AsstProf
# 71    AssocProf
# ...

# %%
df.iloc[:,-1]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
#        ...
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# 66     63100
# 67     90450
# 68     77500
# 69    116450
# 70     78500
# 71     71065
# 72    161101
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
#last column
df.iloc[:,-2]
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# 5       Male
# 6       Male
# 7       Male
# 8       Male
# 9       Male
# 10      Male
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# 15      Male
# 16      Male
# 17      Male
# 18      Male
# 19      Male
# 20      Male
# 21      Male
# 22      Male
# 23      Male
# 24      Male
# 25      Male
# 26      Male
# 27      Male
# 28      Male
# 29      Male
#        ...
# 48    Female
# 49    Female
# 50    Female
# 51    Female
# 52    Female
# 53    Female
# 54    Female
# 55    Female
# 56    Female
# 57    Female
# 58    Female
# 59    Female
# 60    Female
# 61    Female
# 62    Female
# 63    Female
# 64    Female
# 65    Female
# 66    Female
# 67    Female
# 68    Female
# 69    Female
# 70    Female
# 71    Female
# 72    Female
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
#first 7 rows
df.iloc[0:7]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
#first 2 column
df.iloc[:,0:2]
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# 5        Prof          A
# 6   AssocProf          A
# 7        Prof          A
# 8        Prof          A
# 9        Prof          A
# 10       Prof          B
# 11       Prof          B
# 12   AsstProf          B
# 13       Prof          B
# 14       Prof          B
# 15       Prof          B
# 16   AsstProf          B
# 17   AsstProf          B
# 18       Prof          A
# 19       Prof          A
# 20   AsstProf          B
# 21       Prof          A
# 22   AsstProf          A
# 23   AsstProf          A
# 24       Prof          A
# 25       Prof          B
# 26       Prof          A
# 27       Prof          A
# 28   AsstProf          B
# 29       Prof          B
# ..        ...        ...
# 48       Prof          B
# 49       Prof          B
# 50   AsstProf          B
# 51       Prof          B
# 52       Prof          A
# ...

# %%
#first and second rows and first 2 columns
df.iloc[1:3,0:2]
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
#1st and 5th rows
df.iloc[[0,5],[1,3]]
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
#creat a new data frame from the original sorted by the column salary
df_sorted=df.sort_values(by='service').head(12)

# %% [raw]
# df_stored=df.sort_values(by=['service','salary'], ascending=[true,false])

# %%
df_stored.head(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-597366cc97c7> in <module>
# ----> 1 df_stored.head(12)
#
# NameError: name 'df_stored' is not defined

# %%
flights = pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/flights.csv")

# %%
flights.head(12)
# Out:
#     year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0   2013      1    1     517.0        2.0     830.0       11.0      UA
# 1   2013      1    1     533.0        4.0     850.0       20.0      UA
# 2   2013      1    1     542.0        2.0     923.0       33.0      AA
# 3   2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4   2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5   2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6   2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7   2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8   2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9   2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10  2013      1    1     602.0       -8.0     812.0       -8.0      DL
# 11  2013      1    1     606.0       -4.0     858.0      -12.0      AA
#
# ...

# %%
# to find the null or missing values
flights[flights.isnull().any(axis=1)].head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN

# %%
flights.dropna()
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5       2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6       2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7       2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8       2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9       2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10      2013      1    1     602.0       -8.0     812.0       -8.0      DL
# ...

# %%
#multiple statistics are computed per column
flights[['dep_delay','arr_delay']].agg(['min','mean','max'])
# Out:
#         dep_delay    arr_delay
# min    -33.000000   -75.000000
# mean     9.463773     2.094537
# max   1014.000000  1007.000000

# %%
flights.

# %%
flights.describe()
flights.min
flights.max()
flights.mean
flights.median() 
flights.mode
flights.var() 
flightas.std
flights.sem
skew
kurt
Df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-cfac231ddb2a> in <module>
#       1 flights.describe()
#       2 min, max
# ----> 3 mean, median, mode
#       4 var, std
#       5 sem
#
# NameError: name 'mean' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
#evenly sampled time at 200ms intervals
t=np.arange(0.,5.,0.2)
#red dashes,blue squares and green triangles
plt.plot(t,t,'r--',t**3,'g^')
plt.show()
